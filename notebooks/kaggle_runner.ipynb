# %% [markdown]
# # Kaggle Runner — CoT-ComplianceBench (model B)
# Runs resumable 4-bit generation on a free Kaggle P100/T4x2. After the run, click **Save Version -> Save & Run All (Commit)** to persist `/kaggle/working`. To resume next session, add the previous notebook's output as input data and copy the JSONL back into `/kaggle/working`.

# %%
# Cell 1: get the code (explicit folder name keeps paths consistent with config.py)
# !git clone https://github.com/bharathgaddam1712/COT-COMPLIANCE-SAFETY.git cot-compliance-safety
# %cd /kaggle/working/cot-compliance-safety

# %%
# Cell 2: install deps
# !pip -q install -r requirements.txt

# %%
# Cell 3 (optional): resume from a previous Kaggle Dataset
# Add your prior notebook output (or a Dataset) as Input Data, then uncomment:
# import shutil, glob
# from pathlib import Path
# RAW = Path("/kaggle/working/cot-compliance-safety/data/raw")
# RAW.mkdir(parents=True, exist_ok=True)
# for p in glob.glob("/kaggle/input/*/data/raw/*.jsonl") + glob.glob("/kaggle/input/*/*.jsonl"):
#     shutil.copy2(p, RAW / Path(p).name)
# print("restored:", sorted(RAW.glob("*.jsonl")))
print("skip if first run")

# %%
# Cell 4: build job list (only if not reusing one from Colab/Drive)
# !python src/sampling.py

# %%
# Cell 5: run a DIFFERENT model than Colab (parallelize the work)
# !python src/inference.py --model deepseek-r1-8b
