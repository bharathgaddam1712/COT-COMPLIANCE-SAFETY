# %% [markdown]
# # Kaggle Runner — CoT-ComplianceBench (model B)
# Runs resumable 4-bit generation on a free Kaggle P100/T4x2. After the run, click **Save Version -> Save & Run All (Commit)** to persist `/kaggle/working`. To resume next session, add the previous notebook's output as input data and copy the JSONL back into `/kaggle/working`.

# %%
# Cell 1: get the code
# !git clone https://github.com/<you>/cot-compliance-safety.git
# %cd cot-compliance-safety

# %%
# Cell 2: install deps
# !pip -q install -r requirements.txt

# %%
# Cell 3 (optional): resume from a previous Kaggle Dataset
# If you added your prior output as input data, copy it into writable storage:
#   !mkdir -p /kaggle/working/cot-compliance-safety/data/raw
#   !cp /kaggle/input/cot-data/*.jsonl /kaggle/working/cot-compliance-safety/data/raw/
print('skip if first run')

# %%
# Cell 4: build job list (only if not reusing one from Colab/Drive)
# %cd /kaggle/working/cot-compliance-safety/src
# !python sampling.py

# %%
# Cell 5: run a DIFFERENT model than Colab (parallelize the work)
# !python inference.py --model deepseek-r1-8b
