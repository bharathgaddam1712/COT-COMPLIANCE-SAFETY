# %% [markdown]
# # Colab Runner — CoT-ComplianceBench (model A)
# Runs resumable 4-bit generation on a free Colab T4. Re-run cells 1-6 after any disconnect; the pipeline resumes automatically.

# %%
# Cell 1: get the code
# !git clone https://github.com/bharathgaddam1712/COT-COMPLIANCE-SAFETY.git cot-compliance-safety
# %cd /content/cot-compliance-safety

# %%
# Cell 2: persistent data storage (survives disconnects)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Cell 3: install deps
# !pip -q install -r requirements.txt

# %%
# Cell 4: build the job list (run ONCE ever -- it lands in Drive via config.py)
# !python src/sampling.py

# %%
# Cell 5: smoke test BEFORE spending GPU hours
# !python src/smoke_test.py

# %%
# Cell 6: real run -- RE-RUN this after any disconnect, it resumes
# !python src/inference.py --model deepseek-r1-7b
